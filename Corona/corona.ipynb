# %%
from library import *

# %matplotlib inline

# %% [markdown]
# ## download data and save in current folder

# %% [markdown]
# response = requests.get(url)
#
# folder = os.getcwd()
# with open(os.path.join(folder, "test.csv"), 'wb') as f:
#     f.write(response.content)

# %% [markdown]
# ## read data

# %%
europe_data = pd.read_csv('europe.csv')
europe_data.drop(['geoId','countryterritoryCode', 'popData2018'], axis = 1, inplace = True)

# %%
poland = prepare_data(europe_data, 'Poland')
plot_all(poland)
poland
# Out:
# /home/neofelia/Pulpit/Corona/library.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['n'] = np.linspace(len(df),1, len(df)).astype('int')
# /home/neofelia/Pulpit/Corona/library.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['all'] = sum_cases
# /home/neofelia/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
italy = prepare_data(europe_data, 'Italy')
plot_all(italy, max_x = 90, max_y =150000)
italy
# Out:
# parameters: logistic [9.99999940e-01 1.00000000e+00 5.73147169e-08]
# parameters: expo [-2.0847732e-14  1.0000000e+00]
#          dateRep  day  month  year  cases  deaths countriesAndTerritories   n  \
# 4119  03/04/2020    3      4  2020   4668     760                   Italy  95
# 4120  02/04/2020    2      4  2020   4782     727                   Italy  94
# 4121  01/04/2020    1      4  2020   4053     839                   Italy  93
# 4122  31/03/2020   31      3  2020   4050     810                   Italy  92
# 4123  30/03/2020   30      3  2020   5217     758                   Italy  91
# ...          ...  ...    ...   ...    ...     ...                     ...  ..
# 4208  05/01/2020    5      1  2020      0       0                   Italy   6
# 4209  04/01/2020    4      1  2020      0       0                   Italy   5
# 4210  03/01/2020    3      1  2020      0       0                   Italy   4
# ...

# %%
china = prepare_data(europe_data, 'China')
plot_all(china, max_x=90, max_y = 120000)
china
# Out:
# /home/neofelia/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/neofelia/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:795: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/neofelia/Pulpit/Corona/library.py:18: RuntimeWarning: overflow encountered in exp
#   return V/(1+np.exp(k*(x-x0)))
# parameters: logistic [ 3.27028000e+01 -1.56244325e+02  7.03090159e+04]
# parameters: expo [-2.0847732e-14  1.0000000e+00]
#          dateRep  day  month  year  cases  deaths countriesAndTerritories   n  \
# 1640  03/04/2020    3      4  2020     70      10                   China  95
# 1641  02/04/2020    2      4  2020    100       6                   China  94
# 1642  01/04/2020    1      4  2020     54       1                   China  93
# ...

# %%
germany = prepare_data(europe_data, 'Germany')
plot_all(germany, max_x = 90, max_y =80000)
germany
# Out:
# parameters: logistic [9.99999911e-01 9.99999998e-01 7.58169911e-08]
# parameters: expo [-2.0847732e-14  1.0000000e+00]
#          dateRep  day  month  year  cases  deaths countriesAndTerritories   n  \
# 3020  03/04/2020    3      4  2020      0       0                 Germany  95
# 3021  02/04/2020    2      4  2020   6156     140                 Germany  94
# 3022  01/04/2020    1      4  2020   5453     149                 Germany  93
# 3023  31/03/2020   31      3  2020   4615     128                 Germany  92
# 3024  30/03/2020   30      3  2020   4751      66                 Germany  91
# ...          ...  ...    ...   ...    ...     ...                     ...  ..
# 3109  05/01/2020    5      1  2020      0       0                 Germany   6
# 3110  04/01/2020    4      1  2020      0       0                 Germany   5
# 3111  03/01/2020    3      1  2020      0       0                 Germany   4
# ...

# %%
spain = prepare_data(europe_data, 'Spain')
plot_all(spain, max_x = 100, max_y =120000)
spain
# Out:
# parameters: logistic [9.99999927e-01 9.99999999e-01 6.51319748e-08]
# parameters: expo [-2.0847732e-14  1.0000000e+00]
#          dateRep  day  month  year  cases  deaths countriesAndTerritories   n  \
# 7269  03/04/2020    3      4  2020   8102     950                   Spain  95
# 7270  02/04/2020    2      4  2020   7719     864                   Spain  94
# 7271  01/04/2020    1      4  2020   9222     849                   Spain  93
# 7272  31/03/2020   31      3  2020   6398     812                   Spain  92
# 7273  30/03/2020   30      3  2020   6549     838                   Spain  91
# ...          ...  ...    ...   ...    ...     ...                     ...  ..
# 7358  05/01/2020    5      1  2020      0       0                   Spain   6
# 7359  04/01/2020    4      1  2020      0       0                   Spain   5
# 7360  03/01/2020    3      1  2020      0       0                   Spain   4
# ...
